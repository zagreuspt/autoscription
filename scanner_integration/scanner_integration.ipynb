# %% [markdown]
# # Scanner integration
# ## 1 Identify:
# - **Context:** users may face issues to manage two different software solutions
# - **Issue:** want to reduce support time
# - **Why do I care about:** I want to save time and money on the support
# ## 2 Research & Refine:
# ### Requirements:
# - Barcode detection
# - blank page removal
# - auto skew
# - 300x300dpi
# - two side scanning
# - document size fixed A4
# - color settings 24bit
# - rotate image based on text orientation
# - multifeed
# - timeout to restart missing batch
# - filenaming
# - file format jpg
#
# ### Tools:
# #### python sdks:
# - Library Analisys https://www.dynamsoft.com/blog/insights/document-scanning-twain-wia-isis-sane/
# - https://pypi.org/project/pyinsane2/
# - https://github.com/hbldh/brotherscan/blob/master/scan.py
# - https://github.com/soachishti/pyScanLib
#
# Isis driver for brother
# - https://python-sane.readthedocs.io/en/latest/
# - https://pypi.org/project/twain/
# - https://twain.org/wp-content/uploads/2016/03/TWAIN-2.2-Spec.pdf
# - https://pytwain.readthedocs.io/en/latest/
#
# Twain:
# - download 64bit twain dsm dll and add it to windows 32
# - seems to support our requirements, checked autoskewcorection and barcode detection
# - line 1579 set capability for source manager
#
# pyinsane2/libinsane:
# - deprecated replaced by [libinsane](https://gitlab.gnome.org/World/OpenPaperwork/libinsane#readme)
# - supported scanners (https://openpaper.work/scannerdb/vendor/1/)
# - [ironscanner](https://gitlab.gnome.org/littlejo/ironscanner) for information retrieval
#     - brother ads-4300N is not in the supported list but can be used
# - libinsane Cross-API supports Sane (Linux), WIA2 (Windows) and TWAIN (Windows)
# - Cross-programming languages native interface
# - how to use it in python https://doc.openpaper.work/libinsane/latest/libinsane/howto_python.html
# - go to python interface https://pygobject.readthedocs.io/en/latest/
# - Licence LGPL v3+, changes to the library need to be made public
#
#
# Can they support all requirements?
#
# #### standalone tools:
# - [iPrint&Scan (brother)](https://help.brother-usa.com/app/answers/detail/a_id/150551/~/download-and-install-brother-iprint%26scan---windows-or-macintosh-computer)
#     - no command line tool
# - [brother scan essentials](https://help.brother-usa.com/app/answers/detail/a_id/182414/~/scan-using-scanessentials---windows-computer)
# - [brscan-skey tool](https://support.brother.com/g/b/faqend.aspx?c=gb&lang=en&prod=ds920dw_eu&faqid=faq00100611_000)
# - Do they have command line support?
#
# ### powershell commands
# https://superuser.com/questions/684061/automate-windows-scanning-feature
# https://learn.microsoft.com/en-us/previous-versions/windows/desktop/wiaaut/-wiaaut-device
#
# - less flexibility
#
#
# Pseudocode:
#
# TDD:
#
# Implement:
#
# Reflect and Improve:

# %%
$deviceManager = new-object -ComObject WIA.DeviceManager
$device = $deviceManager.DeviceInfos.Item(1).Connect()    

$wiaFormatPNG = "{B96B3CAF-0728-11D3-9D7B-0000F81EF32E}"
foreach ($item in $device.Items) { 
    $image = $item.Transfer($wiaFormatPNG) 
}    

if($image.FormatID -ne $wiaFormatPNG)
{
    $imageProcess = new-object -ComObject WIA.ImageProcess
    $imageProcess.Filters.Add($imageProcess.FilterInfos.Item("Convert").FilterID)
    $imageProcess.Filters.Item(1).Properties.Item("FormatID").Value = $wiaFormatPNG
    $image = $imageProcess.Apply($image)
}

$image.SaveFile("C:/Users/D4md1/Desktop/test.png")
